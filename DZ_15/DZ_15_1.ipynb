# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('2015.csv')
df.head()

sns.relplot(x='Economy (GDP per Capita)', y='Happiness Score', data=df)
# В деньгах счастье. Уровень счастья сильно коррелирует с показателем ВВП на душу населения"
