# %%
import pandas as pd

url = 'https://en.wikipedia.org/wiki/Python_%28programming_language%29'
df1 = pd.read_html(url, attrs = {'class': 'wikitable'}, encoding='utf-8')[0]
df2 = pd.read_html(url, attrs = {'class': 'infobox vevent'}, encoding='utf-8')[0]
display(df1, df2)
# Out:
#                    Type Mutability  \
# 0                  bool  immutable
# 1             bytearray    mutable
# 2                 bytes  immutable
# 3               complex  immutable
# 4                  dict    mutable
# 5             ellipsisa  immutable
# 6                 float  immutable
# 7             frozenset  immutable
# 8                   int  immutable
# 9                  list    mutable
# 10            NoneTypea  immutable
# 11  NotImplementedTypea  immutable
# 12                range  immutable
# 13                  set    mutable
# 14                  str  immutable
# 15                tuple  immutable
#
#                                           Description  \
# 0                                       Boolean value
# 1                                   Sequence of bytes
# 2                                   Sequence of bytes
# 3        Complex number with real and imaginary parts
# 4   Associative array (or dictionary) of key and v...
# ...
