# %%
import pandas as pd

df = pd.read_csv('visit_log.csv', sep=';')
df.head()

""""
Добавляем последовательность координат в таблицу визитов и покупок через user_id и timestamp (расположение 
пользователя во время визита или покупки).
Координаты могут помочь определить город, из которого совершался визит/покупка, что полезно при планировании
открытия отделений компании по регионам. Или расчетам потенциальных расходов на доставку. Кроме того мы получаем 
данные о часовом поясе, что поможет более точно сдлеать анализ пиковой активности сайта.
# Out:
#     timestamp    visit_id                                 url  region  \
# 0  1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3  Russia
# 1  1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a  Russia
# 2  1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15  Russia
# 3  1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15  Russia
# 4  1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15  Russia
#
#       user_id traffic_source
# 0  b1613cc09f         yandex
# 1  4c3ec14bee         direct
# 2  a8c40697fb         yandex
# 3  521ac1d6a0         yandex
# 4  d7323c571c         yandex
